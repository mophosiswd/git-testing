# %% [markdown]
# # Ch 1 Language Processing and Python

# %% [markdown]
# ### Git Testing

# %% [markdown]
# ## 1. Computing with Language: Texts and Words

# %% [markdown]
# ### 1.1 Getting Started with Python

# %%
1+3+5
# Out:
# 9

# %%
1+3+5/2
# Out:
# 6.5

# %%
x = 1+3/2

# %%
print(x)
# Out:
# 2.5

# %% [markdown]
# ### 1.2 Getting Started with NLTK

# %%
import nltk

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %%
text3
# Out:
# <Text: The Book of Genesis>

# %% [markdown]
# ### 1.3 Searching Text

# %%
text1.concordance("monstrous")
# Out:
# Displaying 11 of 11 matches:
# ong the former , one was of a most monstrous size . ... This came towards us ,
# ON OF THE PSALMS . " Touching that monstrous bulk of the whale or ork we have r
# ll over with a heathenish array of monstrous clubs and spears . Some were thick
# d as you gazed , and wondered what monstrous cannibal and savage could ever hav
# that has survived the flood ; most monstrous and most mountainous ! That Himmal
# they might scout at Moby Dick as a monstrous fable , or still worse and more de
# th of Radney .'" CHAPTER 55 Of the Monstrous Pictures of Whales . I shall ere l
# ing Scenes . In connexion with the monstrous pictures of whales , I am strongly
# ere to enter upon those still more monstrous stories of them which are to be fo
# ght have been rummaged out of this monstrous cabinet there is no telling . But
# of Whale - Bones ; for Whales of a monstrous size are oftentimes cast up dead u

# %%
text2.concordance("harmony")
# Out:
# Displaying 2 of 2 matches:
#  same table , and , with the utmost harmony , engaged in forwarding the same wo
# emselves , nothing could exceed the harmony in which they all lived together .

# %%
text2.concordance("affection")
# Out:
# Displaying 25 of 79 matches:
# , however , and , as a mark of his affection for the three girls , he left them
# t . It was very well known that no affection was ever supposed to exist between
# deration of politeness or maternal affection on the side of the former , the tw
# d the suspicion -- the hope of his affection for me may warrant , without impru
# hich forbade the indulgence of his affection . She knew that his mother neither
# rd she gave one with still greater affection . Though her late conversation wit
#  can never hope to feel or inspire affection again , and if her home be uncomfo
# m of the sense , elegance , mutual affection , and domestic comfort of the fami
# , and which recommended him to her affection beyond every thing else . His soci
# ween the parties might forward the affection of Mr . Willoughby , an equally st
#  the most pointed assurance of her affection . Elinor could not be surprised at
# ...

# %%
text3.concordance("lived")
# Out:
# Displaying 25 of 38 matches:
# ay when they were created . And Adam lived an hundred and thirty years , and be
# ughters : And all the days that Adam lived were nine hundred and thirty yea and
# nd thirty yea and he died . And Seth lived an hundred and five years , and bega
# ve years , and begat Enos : And Seth lived after he begat Enos eight hundred an
# welve years : and he died . And Enos lived ninety years , and begat Cainan : An
#  years , and begat Cainan : And Enos lived after he begat Cainan eight hundred
# ive years : and he died . And Cainan lived seventy years and begat Mahalaleel :
# rs and begat Mahalaleel : And Cainan lived after he begat Mahalaleel eight hund
# years : and he died . And Mahalaleel lived sixty and five years , and begat Jar
# s , and begat Jared : And Mahalaleel lived after he begat Jared eight hundred a
# and five yea and he died . And Jared lived an hundred sixty and two years , and
# ...

# %%
text4.concordance("god")
# Out:
# Displaying 25 of 98 matches:
# eliance on the protection of Almighty God , I shall forthwith commence the duti
# humble , acknowledged dependence upon God and His overruling providence . We ha
# great office I must humbly invoke the God of our fathers for wisdom and firmnes
# d the same Bible and pray to the same God , and each invokes His aid against th
# hat any men should dare to ask a just God ' s assistance in wringing their brea
# offenses which , in the providence of God , must needs come , but which , havin
# butes which the believers in a living God always ascribe to Him ? Fondly do we
# war may speedily pass away . Yet , if God wills that it continue until all the
# r all , with firmness in the right as God gives us to see the right , let us st
# the prayers of the nation to Almighty God in behalf of this consummation . Fell
# r , they have " followed the light as God gave them to see the light ." They ar
# ...

# %%
text5.concordance("lol")
# Out:
# Displaying 25 of 822 matches:
# ast PART 24 / m boo . 26 / m and sexy lol U115 boo . JOIN PART he drew a girl w
# ope he didnt draw a penis PART ewwwww lol & a head between her legs JOIN JOIN s
# a bowl i got a blunt an a bong ...... lol JOIN well , glad it worked out my cha
# e " PART Hi U121 in ny . ACTION would lol @ U121 . . . but appearently she does
# 30 make sure u buy a nice ring for U6 lol U7 Hi U115 . ACTION isnt falling for
#  didnt ya hear !!!! PART JOIN geeshhh lol U6 PART hes deaf ppl here dont get it
# es nobody here i wanna misbeahve with lol JOIN so read it . thanks U7 .. Im hap
# ies want to chat can i talk to him !! lol U121 !!! forwards too lol JOIN ALL PE
# k to him !! lol U121 !!! forwards too lol JOIN ALL PErvs ... redirect to U121 '
#  loves ME the most i love myself JOIN lol U44 how do u know that what ? jerkett
# ng wrong ... i can see it in his eyes lol U20 = fiance Jerketts lmao wtf yah I
# ...

# %%
text1.similar("monstrous")
# Out:
# true contemptible christian abundant few part mean careful puzzled
# mystifying passing curious loving wise doleful gamesome singular
# delightfully perilous fearless

# %%
text2.similar("monstrous")
# Out:
# very so exceedingly heartily a as good great extremely remarkably
# sweet vast amazingly

# %%
text2.common_contexts(["monstrous", "very"])
# Out:
# a_pretty am_glad a_lucky is_pretty be_glad

# %%
text2.common_contexts(["monstrous", "great"])
# Out:
# a_deal

# %%
text1.similar("harmony")
# Out:
# lord nothing instinct sleet contract nourished drunk longitude uneven

# %%
text2.similar("harmony")
# Out:
# family manner alteration house gentleman way improvement rest time
# prospect place delight business world truth ladies objects fire matter
# point

# %%
text2.common_contexts(["harmony", "engaged"])
# Out:
# No common contexts were found

# %%
text4.dispersion_plot(["citizens", "democracy", "freedom", "duties"])

# %%
# generate() function does not work in Python 3 but will be back in the later versions
text3.generate()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-e0816ba18b61> in <module>()
# ----> 1 text3.generate()
#
# TypeError: generate() missing 1 required positional argument: 'words'

# %% [markdown]
# ### 1.4 Counting Vocabulary

# %%
print (len(text3))
print (len(set(text3)))
# Out:
# 44764
# 2789

# %%
sorted(set(text3))
# Out:
# ['!',
#  "'",
#  '(',
#  ')',
#  ',',
#  ',)',
#  '.',
#  '.)',
#  ':',
#  ';',
#  ';)',
#  '?',
#  '?)',
#  'A',
#  'Abel',
#  'Abelmizraim',
#  'Abidah',
#  'Abide',
#  'Abimael',
#  'Abimelech',
#  'Abr',
#  'Abrah',
#  'Abraham',
#  'Abram',
#  'Accad',
#  'Achbor',
#  'Adah',
#  'Adam',
#  'Adbeel',
#  'Admah',
#  'Adullamite',
#  'After',
#  'Aholibamah',
#  'Ahuzzath',
#  'Ajah',
#  'Akan',
#  'All',
#  'Allonbachuth',
#  'Almighty',
#  'Almodad',
#  'Also',
#  'Alvah',
#  'Alvan',
#  'Am',
#  'Amal',
#  'Amalek',
#  'Amalekites',
#  'Ammon',
#  'Amorite',
#  'Amorites',
#  'Amraphel',
#  'An',
#  'Anah',
#  'Anamim',
#  'And',
#  'Aner',
#  'Angel',
#  'Appoint',
#  'Aram',
#  'Aran',
#  'Ararat',
#  'Arbah',
#  'Ard',
#  'Are',
#  'Areli',
#  'Arioch',
#  'Arise',
#  'Arkite',
#  'Arodi',
#  'Arphaxad',
#  'Art',
#  'Arvadite',
#  'As',
#  'Asenath',
#  'Ashbel',
#  'Asher',
#  'Ashkenaz',
#  'Ashteroth',
#  'Ask',
#  'Asshur',
#  'Asshurim',
#  'Assyr',
#  'Assyria',
# ...

# %%
len(set(text3))/len(text3)
# Out:
# 0.06230453042623537

# %%
text3.count("smote")
# Out:
# 5

# %%
text4.count('a')*100/len(text4)
# Out:
# 1.4643016433938312

# %%
text5.count("lol")

# %%
text5.count("lol")*100/len(text5)
# Out:
# 1.5640968673628082

# %%
def lexical_diversity(text):
    return len(set(text))/len(text)

def percentage(count, total):
    return 100 * count / total

# %%
lexical_diversity(text3)
# Out:
# 0.06230453042623537

# %%
lexical_diversity(text5)
# Out:
# 0.13477005109975562

# %%
percentage (4, 5)
# Out:
# 80.0

# %%
percentage(text4.count('a'), len(text4))
# Out:
# 1.4643016433938312

# %% [markdown]
# ## 2. A Closer Look at Python

# %% [markdown]
# ### 2.1 Lists

# %%
sent1 = ['Call', 'me', 'Ishmael', '.']

# %%
sent1
# Out:
# ['Call', 'me', 'Ishmael', '.']

# %%
len(sent1)
# Out:
# 4

# %%
lexical_diversity(sent1)
# Out:
# 1.0

# %%
ex1 = ['Monty', 'Python', 'and', 'the', 'Holy', 'Grail']

# %%
sorted(ex1)
# Out:
# ['Grail', 'Holy', 'Monty', 'Python', 'and', 'the']

# %%
len(ex1)
# Out:
# 6

# %%
len(set(ex1))
# Out:
# 6

# %%
ex1.count('the')
# Out:
# 1

# %%
['Monty', 'Python'] + ['and', 'the', 'Holy', 'Grail']
# Out:
# ['Monty', 'Python', 'and', 'the', 'Holy', 'Grail']

# %%
sent2
# Out:
# ['The',
#  'family',
#  'of',
#  'Dashwood',
#  'had',
#  'long',
#  'been',
#  'settled',
#  'in',
#  'Sussex',
#  '.']

# %%
sent3
# Out:
# ['In',
#  'the',
#  'beginning',
#  'God',
#  'created',
#  'the',
#  'heaven',
#  'and',
#  'the',
#  'earth',
#  '.']

# %%
sent4 + sent1
# Out:
# ['Fellow',
#  '-',
#  'Citizens',
#  'of',
#  'the',
#  'Senate',
#  'and',
#  'of',
#  'the',
#  'House',
#  'of',
#  'Representatives',
#  ':',
#  'Call',
#  'me',
#  'Ishmael',
#  '.']

# %%
sent1.append("Some")
sent1
# Out:
# ['Call', 'me', 'Ishmael', '.', 'Some']

# %% [markdown]
# ### 2.2 Indexing Lists

# %%
text1.count('heaven')
# Out:
# 40

# %%
text4[173]
# Out:
# 'awaken'

# %%
text4.index('awaken')
# Out:
# 173

# %%
text4[0]
# Out:
# 'Fellow'

# %%
text4[1]
# Out:
# '-'

# %%
count = 1
for word in text4:
    if count <= 10:
        print(word)
        count = count + 1
    else:
        exit
# Out:
# Fellow
# -
# Citizens
# of
# the
# Senate
# and
# of
# the
# House

# %%
text5[0:9]
# Out:
# ['now', 'im', 'left', 'with', 'this', 'gay', 'name', ':P', 'PART']

# %%
text5[1:9]
# Out:
# ['im', 'left', 'with', 'this', 'gay', 'name', ':P', 'PART']

# %%
text5[16715:16735]
# Out:
# ['U86',
#  'thats',
#  'why',
#  'something',
#  'like',
#  'gamefly',
#  'is',
#  'so',
#  'good',
#  'because',
#  'you',
#  'can',
#  'actually',
#  'play',
#  'a',
#  'full',
#  'game',
#  'without',
#  'buying',
#  'it']

# %%
text6[1600:1625]
# Out:
# ['We',
#  "'",
#  're',
#  'an',
#  'anarcho',
#  '-',
#  'syndicalist',
#  'commune',
#  '.',
#  'We',
#  'take',
#  'it',
#  'in',
#  'turns',
#  'to',
#  'act',
#  'as',
#  'a',
#  'sort',
#  'of',
#  'executive',
#  'officer',
#  'for',
#  'the',
#  'week']

# %%
sent = ['word1', 'word2', 'word3', 'word4', 'word5',
'word6', 'word7', 'word8', 'word9', 'word10']

print (sent[0])
print (sent[9])
# Out:
# word1
# word10

# %%
sent[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-94-146a2a32f068> in <module>()
# ----> 1 sent[10]
#
# IndexError: list index out of range

# %%
sent[5:8]
# Out:
# ['word6', 'word7', 'word8']

# %%
sent[:3]
# Out:
# ['word1', 'word2', 'word3']

# %%
text2[141525:]
# Out:
# ['among',
#  'the',
#  'merits',
#  'and',
#  'the',
#  'happiness',
#  'of',
#  'Elinor',
#  'and',
#  'Marianne',
#  ',',
#  'let',
#  'it',
#  'not',
#  'be',
#  'ranked',
#  'as',
#  'the',
#  'least',
#  'considerable',
#  ',',
#  'that',
#  'though',
#  'sisters',
#  ',',
#  'and',
#  'living',
#  'almost',
#  'within',
#  'sight',
#  'of',
#  'each',
#  'other',
#  ',',
#  'they',
#  'could',
#  'live',
#  'without',
#  'disagreement',
#  'between',
#  'themselves',
#  ',',
#  'or',
#  'producing',
#  'coolness',
#  'between',
#  'their',
#  'husbands',
#  '.',
#  'THE',
#  'END']

# %%
sent[0] = 'First'
sent[9] = 'Last'
print (sent)
print (len(sent))
# Out:
# ['First', 'word2', 'word3', 'word4', 'word5', 'word6', 'word7', 'word8', 'word9', 'Last']
# 10

# %%
sent[1:9] = ['Second', 'Third']
sent
# Out:
# ['First', 'Second', 'Third', 'Last']

# %%
sent[9]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-100-0e31928eddd3> in <module>()
# ----> 1 sent[9]
#
# IndexError: list index out of range

# %% [markdown]
# ### 2.3 Variables

# %%
my_sent = ['Bravely', 'bold', 'Sir', 'Robin', ',', 'rode',
... 'forth', 'from', 'Camelot', '.']
noun_phase = my_sent[1:4]
noun_phase
# Out:
# ['bold', 'Sir', 'Robin']

# %%
wOrDs = sorted(noun_phase)
wOrDs
# Out:
# ['Robin', 'Sir', 'bold']

# %%
not = 'Camelot'
# Out:
#   File "<ipython-input-108-d12e7e70e097>", line 1
#     not = 'Camelot'
#         ^
# SyntaxError: invalid syntax

# %%
vocab = set(text1)
vocab_size = len(vocab)
vocab_size
# Out:
# 19317

# %% [markdown]
# ### 2.4 Strings

# %%
# Access the elements of a word
name = 'Monty'
print (name[0])
print (name[:4])
# Out:
# M
# Mont

# %%
print (name * 2)
print (name + '!')
print (name)
# Out:
# MontyMonty
# Monty!
# Monty

# %%
' '.join(['Monty', 'Python'])
# Out:
# 'Monty Python'

# %%
'Monty Python'.split()
# Out:
# ['Monty', 'Python']

# %% [markdown]
# ## 3. Computing with Language: Simple Statistics

# %%
saying = ['After', 'all', 'is', 'said', 'and', 'done',
...           'more', 'is', 'said', 'than', 'done']
print (len(saying))
tokens = set(saying)
print (len(tokens))
tokens = sorted(tokens)
print (tokens)
print (tokens[-2:])
print (tokens[-1:])
print (tokens[7])
# Out:
# 11
# 8
# ['After', 'all', 'and', 'done', 'is', 'more', 'said', 'than']
# ['said', 'than']
# ['than']
# than

# %% [markdown]
# ### 3.1 Frequency Distributions

# %%
fdist1 = FreqDist(text1)
print (fdist1)
#list(fdist1.keys())
fdist1.most_common(10)
# Out:
# <FreqDist with 19317 samples and 260819 outcomes>
# [(',', 18713),
#  ('the', 13721),
#  ('.', 6862),
#  ('of', 6536),
#  ('and', 6024),
#  ('a', 4569),
#  ('to', 4542),
#  (';', 4072),
#  ('in', 3916),
#  ('that', 2982)]

# %%
fdist1['whale']
# Out:
# 906

# %%
fdist1['the']
# Out:
# 13721

# %%
# pratice example
fdist2 = FreqDist(text2)
print (fdist2)
print (fdist2.most_common(10))
# Out:
# <FreqDist with 6833 samples and 141576 outcomes>
# [(',', 9397), ('to', 4063), ('.', 3975), ('the', 3861), ('of', 3565), ('and', 3350), ('her', 2436), ('a', 2043), ('I', 2004), ('in', 1904)]

# %%
fdist2['human']
# Out:
# 4

# %%
fdist1.plot(10, cumulative=True)

# %%
print (len(text1))
fdist1.plot(50, cumulative=True)

# 50 words account for nearly half the book
# Out:
# 260819

# %%
fdist2.plot(10, cumulative=True)

# %%
print(len(text2))
fdist2.plot(50, cumulative=True)
# Out:
# 141576

# %%
fdist1.plot(10, cumulative=False)

# %%
fdist2.plot(10, cumulative=False)

# %% [markdown]
# #### 3.2 Fine-grained Selection of Words

# %%
# Find words from the text that are more than 15 characters

V = set(text1)
long_words = [w for w in V if len(w) > 15]

sorted(long_words)
# Out:
# ['CIRCUMNAVIGATION',
#  'Physiognomically',
#  'apprehensiveness',
#  'cannibalistically',
#  'characteristically',
#  'circumnavigating',
#  'circumnavigation',
#  'circumnavigations',
#  'comprehensiveness',
#  'hermaphroditical',
#  'indiscriminately',
#  'indispensableness',
#  'irresistibleness',
#  'physiognomically',
#  'preternaturalness',
#  'responsibilities',
#  'simultaneousness',
#  'subterraneousness',
#  'supernaturalness',
#  'superstitiousness',
#  'uncomfortableness',
#  'uncompromisedness',
#  'undiscriminating',
#  'uninterpenetratingly']

# %%
V2 = set(text5)
long_words2 = [word for word in V2 if len(word) > 15]
sorted(long_words2)
# Out:
# ['!!!!!!!!!!!!!!!!',
#  '!!!!!!!!!!!!!!!!!!!!!!',
#  '!!!!!!!!!!!!!!!!!!!!!!!',
#  '!!!!!!!!!!!!!!!!!!!!!!!!!!!',
#  '!!!!!!!!!!!!!!!!!!!!!!!!!!!!',
#  '!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!',
#  '#talkcity_adults',
#  '(((((((((((((((((',
#  '((((((((((((((((((',
#  '((((((((((((((((((((',
#  '(((((((((((((((((((((',
#  '(((((((((((((((((((((((',
#  '((((((((((((((((((((((((',
#  '(((((((((((((((((((((((((',
#  '((((((((((((((((((((((((((',
#  ')))))))))))))))))',
#  ')))))))))))))))))))',
#  ')))))))))))))))))))))',
#  '))))))))))))))))))))))',
#  '))))))))))))))))))))))))))))',
#  ')))))))))))))))))))))))))))))))',
#  '--------------------',
#  '.(..(.vMp3 v1.7.4.).)',
#  '.(..(.vMp3 vi.p.t.)..).',
#  '................',
#  '..................',
#  '...................',
#  '....................',
#  '........................',
#  '..............................',
#  '.A.n.a.c.?.n.?.a.',
#  '//www.wunderground.com/cgi-bin/findweather/getForecast?query=95953#FIR',
# ...

# %%
fdist5 = FreqDist(text5)

sorted(w for w in set(text5) if len(w) > 7 and fdist5[w] > 7)
# Out:
# ['#14-19teens',
#  '#talkcity_adults',
#  '((((((((((',
#  '........',
#  'Question',
#  'actually',
#  'anything',
#  'computer',
#  'cute.-ass',
#  'everyone',
#  'football',
#  'innocent',
#  'listening',
#  'remember',
#  'seriously',
#  'something',
#  'together',
#  'tomorrow',
#  'watching']

# %%
importantWords = [w for w in set(text5) if len(w)>7 and fdist5[w]>7]

sorted(importantWords)
# Out:
# ['#14-19teens',
#  '#talkcity_adults',
#  '((((((((((',
#  '........',
#  'Question',
#  'actually',
#  'anything',
#  'computer',
#  'cute.-ass',
#  'everyone',
#  'football',
#  'innocent',
#  'listening',
#  'remember',
#  'seriously',
#  'something',
#  'together',
#  'tomorrow',
#  'watching']

# %% [markdown]
# ### 3.3 Collocations and Bigrams

# %%
from nltk.util import bigrams

# %%
bigramReady = bigrams(['more', 'is', 'said', 'than', 'done'])
list(bigramReady)
# Out:
# [('more', 'is'), ('is', 'said'), ('said', 'than'), ('than', 'done')]

# %%
text4.collocations()
# Out:
# United States; fellow citizens; four years; years ago; Federal
# Government; General Government; American people; Vice President; Old
# World; Almighty God; Fellow citizens; Chief Magistrate; Chief Justice;
# God bless; every citizen; Indian tribes; public debt; one another;
# foreign nations; political parties

# %%
text8.collocations()
# Out:
# would like; medium build; social drinker; quiet nights; non smoker;
# long term; age open; Would like; easy going; financially secure; fun
# times; similar interests; Age open; weekends away; poss rship; well
# presented; never married; single mum; permanent relationship; slim
# build

# %% [markdown]
# ### 3.4 Counting Other Things

# %%
[len(w) for w in text1]
# Out:
# [1,
#  4,
#  4,
#  2,
#  6,
#  8,
#  4,
#  1,
#  9,
#  1,
#  1,
#  8,
#  2,
#  1,
#  4,
#  11,
#  5,
#  2,
#  1,
#  7,
#  6,
#  1,
#  3,
#  4,
#  5,
#  2,
#  10,
#  2,
#  4,
#  1,
#  5,
#  1,
#  4,
#  1,
#  3,
#  5,
#  1,
#  1,
#  3,
#  3,
#  3,
#  1,
#  2,
#  3,
#  4,
#  7,
#  3,
#  3,
#  8,
#  3,
#  8,
#  1,
#  4,
#  1,
#  5,
#  12,
#  1,
#  9,
#  11,
#  4,
#  3,
#  3,
#  3,
#  5,
#  2,
#  3,
#  3,
#  5,
#  7,
#  2,
#  3,
#  5,
#  1,
#  2,
#  5,
#  2,
#  4,
#  3,
#  3,
#  8,
#  1,
#  2,
#  7,
#  6,
#  8,
#  3,
#  2,
#  3,
#  9,
#  1,
#  1,
#  5,
#  3,
#  4,
#  2,
#  4,
#  2,
#  6,
#  6,
#  1,
#  3,
#  2,
#  5,
#  4,
#  2,
#  4,
#  4,
#  1,
#  5,
#  1,
#  4,
#  2,
#  2,
#  2,
#  6,
#  2,
#  3,
#  6,
#  7,
#  3,
#  1,
#  7,
#  9,
#  1,
#  3,
#  6,
#  1,
#  1,
#  5,
#  6,
#  5,
#  6,
#  3,
#  13,
#  2,
#  3,
#  4,
#  1,
#  3,
#  7,
#  4,
#  5,
#  2,
#  3,
#  4,
#  2,
#  2,
#  8,
#  1,
#  5,
#  1,
#  3,
#  2,
#  1,
#  3,
#  3,
#  1,
#  4,
#  1,
#  4,
#  6,
#  2,
#  5,
#  4,
#  9,
# ...

# %%
fdist = FreqDist(len(w) for w in text1)
print (fdist)
# Out:
# <FreqDist with 19 samples and 260819 outcomes>

# %%
fdist
# Out:
# FreqDist({1: 47933,
#           2: 38513,
#           3: 50223,
#           4: 42345,
#           5: 26597,
#           6: 17111,
#           7: 14399,
#           8: 9966,
#           9: 6428,
#           10: 3528,
#           11: 1873,
#           12: 1053,
#           13: 567,
#           14: 177,
#           15: 70,
#           16: 22,
#           17: 12,
#           18: 1,
#           20: 1})

# %%
fdist.most_common(10)
# Out:
# [(3, 50223),
#  (1, 47933),
#  (4, 42345),
#  (2, 38513),
#  (5, 26597),
#  (6, 17111),
#  (7, 14399),
#  (8, 9966),
#  (9, 6428),
#  (10, 3528)]

# %%
fdist.plot(10, cumulative=True)

# %%
print (fdist.max())

print (fdist[3])

print (fdist.freq(3))

# words of length 3 account for roughly 20% of the text
# Out:
# 3
# 50223
# 0.19255882431878046

# %% [markdown]
# ## 4. Back to Python: Making Decisions and Taking Control

# %% [markdown]
# ### 4.1 Conditionals

# %% [markdown]
# <	less than   ( > greather than)
#
# <=	less than or equal to ( >= greather than or equal to)
#
# ==	equal to (note this is two "=" signs, not one)
#
# !=	not equal to

# %%
# if sent7 is undefined, do
# from nltk.book import * 

print (sent7)

[w for w in sent7 if len(w) == 4]
# Out:
# ['Pierre', 'Vinken', ',', '61', 'years', 'old', ',', 'will', 'join', 'the', 'board', 'as', 'a', 'nonexecutive', 'director', 'Nov.', '29', '.']
# ['will', 'join', 'Nov.']

# %% [markdown]
# Function	Meaning
#
# s.startswith(t)	test if s starts with t
#
# s.endswith(t)	test if s ends with t
#
# t in s	test if t is a substring of s
#
# s.islower()	test if s contains cased characters and all are lowercase
#
# s.isupper()	test if s contains cased characters and all are uppercase
#
# s.isalpha()	test if s is non-empty and all characters in s are alphabetic
#
# s.isalnum()	test if s is non-empty and all characters in s are alphanumeric
#
# s.isdigit()	test if s is non-empty and all characters in s are digits
#
# s.istitle()	test if s contains cased characters and is titlecased (i.e. all words in s have initial capitals)

# %%
sorted(w for w in set(text1) if w.endswith('ableness'))
# Out:
# ['comfortableness',
#  'honourableness',
#  'immutableness',
#  'indispensableness',
#  'indomitableness',
#  'intolerableness',
#  'palpableness',
#  'reasonableness',
#  'uncomfortableness']

# %%
sorted(term for term in set(text4) if 'gnt' in term)
# Out:
# ['Sovereignty', 'sovereignties', 'sovereignty']

# %%
sorted(item for item in set(sent7) if item.isdigit())
# Out:
# ['29', '61']

# %%
sorted(w for w in set(text7) if '-' in w and 'index' in w)
# Out:
# ['Stock-index',
#  'index-arbitrage',
#  'index-fund',
#  'index-options',
#  'index-related',
#  'stock-index']

# %%
print (sent7)

sorted(w for w in set(sent7) if not w.islower())
# Out:
# ['Pierre', 'Vinken', ',', '61', 'years', 'old', ',', 'will', 'join', 'the', 'board', 'as', 'a', 'nonexecutive', 'director', 'Nov.', '29', '.']
# [',', '.', '29', '61', 'Nov.', 'Pierre', 'Vinken']

# %% [markdown]
# ### Operating on Every Element

# %%
[len(w) for w in text1]
# Out:
# [1,
#  4,
#  4,
#  2,
#  6,
#  8,
#  4,
#  1,
#  9,
#  1,
#  1,
#  8,
#  2,
#  1,
#  4,
#  11,
#  5,
#  2,
#  1,
#  7,
#  6,
#  1,
#  3,
#  4,
#  5,
#  2,
#  10,
#  2,
#  4,
#  1,
#  5,
#  1,
#  4,
#  1,
#  3,
#  5,
#  1,
#  1,
#  3,
#  3,
#  3,
#  1,
#  2,
#  3,
#  4,
#  7,
#  3,
#  3,
#  8,
#  3,
#  8,
#  1,
#  4,
#  1,
#  5,
#  12,
#  1,
#  9,
#  11,
#  4,
#  3,
#  3,
#  3,
#  5,
#  2,
#  3,
#  3,
#  5,
#  7,
#  2,
#  3,
#  5,
#  1,
#  2,
#  5,
#  2,
#  4,
#  3,
#  3,
#  8,
#  1,
#  2,
#  7,
#  6,
#  8,
#  3,
#  2,
#  3,
#  9,
#  1,
#  1,
#  5,
#  3,
#  4,
#  2,
#  4,
#  2,
#  6,
#  6,
#  1,
#  3,
#  2,
#  5,
#  4,
#  2,
#  4,
#  4,
#  1,
#  5,
#  1,
#  4,
#  2,
#  2,
#  2,
#  6,
#  2,
#  3,
#  6,
#  7,
#  3,
#  1,
#  7,
#  9,
#  1,
#  3,
#  6,
#  1,
#  1,
#  5,
#  6,
#  5,
#  6,
#  3,
#  13,
#  2,
#  3,
#  4,
#  1,
#  3,
#  7,
#  4,
#  5,
#  2,
#  3,
#  4,
#  2,
#  2,
#  8,
#  1,
#  5,
#  1,
#  3,
#  2,
#  1,
#  3,
#  3,
#  1,
#  4,
#  1,
#  4,
#  6,
#  2,
#  5,
#  4,
#  9,
# ...

# %%
[w.upper() for w in text1]
# Out:
# ['[',
#  'MOBY',
#  'DICK',
#  'BY',
#  'HERMAN',
#  'MELVILLE',
#  '1851',
#  ']',
#  'ETYMOLOGY',
#  '.',
#  '(',
#  'SUPPLIED',
#  'BY',
#  'A',
#  'LATE',
#  'CONSUMPTIVE',
#  'USHER',
#  'TO',
#  'A',
#  'GRAMMAR',
#  'SCHOOL',
#  ')',
#  'THE',
#  'PALE',
#  'USHER',
#  '--',
#  'THREADBARE',
#  'IN',
#  'COAT',
#  ',',
#  'HEART',
#  ',',
#  'BODY',
#  ',',
#  'AND',
#  'BRAIN',
#  ';',
#  'I',
#  'SEE',
#  'HIM',
#  'NOW',
#  '.',
#  'HE',
#  'WAS',
#  'EVER',
#  'DUSTING',
#  'HIS',
#  'OLD',
#  'LEXICONS',
#  'AND',
#  'GRAMMARS',
#  ',',
#  'WITH',
#  'A',
#  'QUEER',
#  'HANDKERCHIEF',
#  ',',
#  'MOCKINGLY',
#  'EMBELLISHED',
#  'WITH',
#  'ALL',
#  'THE',
#  'GAY',
#  'FLAGS',
#  'OF',
#  'ALL',
#  'THE',
#  'KNOWN',
#  'NATIONS',
#  'OF',
#  'THE',
#  'WORLD',
#  '.',
#  'HE',
#  'LOVED',
#  'TO',
#  'DUST',
#  'HIS',
#  'OLD',
#  'GRAMMARS',
#  ';',
#  'IT',
#  'SOMEHOW',
#  'MILDLY',
#  'REMINDED',
#  'HIM',
#  'OF',
#  'HIS',
#  'MORTALITY',
#  '.',
#  '"',
# ...

# %%
# list comprehension

print (len(text1))
print (len(set(text1)))

print(len(set(word.lower() for word in text1)))

print (len(set(word.lower() for word in text1 if word.isalpha())))
# Out:
# 260819
# 19317
# 17231
# 16948

# %% [markdown]
# ### 4.3 Nested Code Blocks

# %%
# if Python 2.6 or 2.7 is used, have the following
# from __future__ import print_function

word = 'cat'

if len(word) < 5:
    print ('word length is less than 5')
# Out:
# word length is less than 5

# %%
for word in ['Call', 'me', 'Ishmael', '.']:
    print (word)
# Out:
# Call
# me
# Ishmael
# .

# %% [markdown]
# #### 4.4 Looping with Conditions

# %%
sent1 = ['Call', 'me', 'Ishmael', '.']

for xyzzy in sent1:
    if xyzzy.endswith('l'):
        print (xyzzy)
# Out:
# Call
# Ishmael

# %%
for token in sent1:
    if token.islower():
        print(token, 'is a lower case word')
    elif token.istitle():
        print(token, 'is a titlecase word')
    else:
        print(token, 'is punctuation')
# Out:
# Call is a titlecase word
# me is a lower case word
# Ishmael is a titlecase word
# . is punctuation

# %%
tricky = sorted(w for w in set(text2) if 'cie' in w or 'cei' in w)

for word in tricky:
    print (word, end='\n')
# Out:
# ancient
# ceiling
# conceit
# conceited
# conceive
# conscience
# conscientious
# conscientiously
# deceitful
# deceive
# deceived
# deceiving
# deficiencies
# deficiency
# deficient
# delicacies
# excellencies
# fancied
# insufficiency
# insufficient
# legacies
# perceive
# perceived
# perceiving
# prescience
# prophecies
# receipt
# receive
# received
# receiving
# society
# species
# sufficient
# sufficiently
# undeceive
# undeceiving

# %% [markdown]
# ## 5. Automatic Natural Language Understanding

# %% [markdown]
# 5.1 Word sense disambiguation
#
# 5.2 pronoun resolution
#
# 5.3 Generating language output
#
# 5.4 Machine translation through text alignment
#
#     Ex: "How long before the next flight to Alice Springs?"
#
#     Try this yourself using:
#
#     http://translationparty.com/
#
# 5.5 Spoken dialog systems
#
#     Have a converation with an NLTK chatbot:
#
#     nltk.chat.chatbots()
#
# 5.6 Textual entailment

# %%
#nltk.chat.chatbots()

# %% [markdown]
# ## Python Summary

# %%
# To derive the vocabulary, collapsing case distinctions and ignoring punctuation, we can write

set(w.lower() for w in text1 if w.isalpha())
# Out:
# {'commercial',
#  'engaged',
#  'purposely',
#  'syllable',
#  'hempen',
#  'spectre',
#  'lipless',
#  'paved',
#  'sallies',
#  'wakened',
#  'occupied',
#  'button',
#  'gladness',
#  'ascertained',
#  'kind',
#  'butterless',
#  'lavater',
#  'tack',
#  'imbecile',
#  'europe',
#  'immense',
#  'tattooed',
#  'spiritual',
#  'quadruped',
#  'an',
#  'herman',
#  'stun',
#  'ugliest',
#  'evoke',
#  'skins',
#  'predicted',
#  'breaths',
#  'oly',
#  'learnedly',
#  'pours',
#  'modifications',
#  'altitude',
#  'healthful',
#  'dar',
#  'seniors',
#  'sidelong',
#  'encounter',
#  'depend',
#  'organ',
#  'constantine',
#  'scrimps',
#  'breathed',
#  'clock',
#  'at',
#  'invests',
#  'affected',
#  'malays',
#  'thorough',
#  'fiend',
#  'gore',
#  'monsoons',
#  'frenzies',
#  'hearsed',
#  'pantaloon',
#  'crumpled',
#  'foam',
#  'deceived',
#  'wellington',
#  'compliance',
#  'salamander',
#  'flourishing',
#  'conflicts',
#  'exciting',
#  'embellished',
#  'converted',
# ...

# %%
# Defining a function

def mult(x, y):
    return x * y

# %%
mult(2, 3)
# Out:
# 6

# %% [markdown]
# ## Further Reading

# %% [markdown]
# http://nltk.org
#
# Python documentation:
# http://docs.pythonorg
#
# Beginner's Guide to Python:
# http://wiki.pythob.org/moin/BeginnersGuide
#
# NLP reference books:
#
# Indurkhya, Nitin and Fred Damerau (eds, 2010) Handbook of Natural Language Processing (Second Edition) Chapman & Hall/CRC. 2010. (Indurkhya & Damerau, 2010) (Dale, Moisl, & Somers, 2000)
#
# Jurafsky, Daniel and James Martin (2008) Speech and Language Processing (Second Edition). Prentice Hall. (Jurafsky & Martin, 2008)
#
# Mitkov, Ruslan (ed, 2003) The Oxford Handbook of Computational Linguistics. Oxford University Press. (second edition expected in 2010). (Mitkov, 2002)

# %% [markdown]
# ## Exercises
